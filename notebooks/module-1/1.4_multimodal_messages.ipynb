# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi world, the Moon itself is a polity, and its capital is:
#
# Lunaris Prime
#
# - Location: Nestled on the rim of Shackleton Crater in the south polar region, where some solar vantage points keep the city bathed in daylight while other areas stay in cool shadow for ice extraction. The urban core sits inside a ring of shielded domes and radiating transit tunnels.
#
# - Government: The Lunar Conclave, led by a Chancellor, rules from Lunaris Prime. The city houses the Movable Senate and the Lunar Archive, the spiritual and practical heart of policy, science, and law.
#
# - Architecture and living: A city of glass and basalt, built under transparent domes that protect inhabitants from vacuum and micrometeorites. Inside, gravity is gently simulated in the main districts to keep daily life comfortable. Streets run in broad arcs with magnetic-lev transit tubes, and sky-lit atria connect markets, schools, and labs.
#
# - Economy: Energy from towering solar farms dominates; water ice mined from permanently shadowed pockets is processed into life-support systems and fuel. Helium-3, ices, and 3D-printed components form the backbone of industry.
#
# - Culture: A fusion of Earth cultures with lunar-inherited traditions. Night and day blur inside the domes, but the city hosts frequent “Aurora Dinners” and holo-lit festivals that mimic natural skies. Public spaces emphasize science, art, and exploration.
#
# - Landmarks: The Helio Arch (a solar-lens gateway), the Ice Choir Hall (an acoustically perfect dome), and the Lagrange Library (a cutting-edge research complex). The government center, Asteria Gate, sits at the heart of the civic district.
#
# - Daily life snippet: In the market district, people in exo-shells scroll holographic menus while vendors trade in rare lunar minerals and bioengineered crops grown in pressure-controlled domes. Above, a luminous aurora-like display dances through the dome ceiling as a lunar choir rehearses.
#
# If you’d like, I can tailor Lunaris Prime further—adjust its layout, history, notable figures, or create a map-style description of districts and transit routes.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': '故宫.png', 'type': 'image/png', 'size': 4824577, 'content': <memory at 0x10fef7ac0>, 'last_modified': datetime.datetime(2026, 4, 5, 13, 16, 16, 811000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# What you’re looking at is a capital city that fuses an ancient imperial aesthetic with a far-future civics. I’ll describe it as a single, coherent world for you.
#
# Name and setting
# - Capital name: Jingdu, often called the Jade Capital. It’s the ceremonial seat of the Celestial Dynasty, a federation that blends centuries-old court tradition with ultra-modern governance.
# - Geography: perched on a high terrace above a winding delta, Jingdu is ringed by ceremonial gates and a network of canals. The centerpiece is the Imperial City, a stair-stepped complex that climbs toward a citadel where the ruling council meets.
#
# Cityscape and architecture
# - The Imperial City: tiered temples and pavilions with sweeping, upturned eaves clad in gold-tinted copper. The wooden frames are reinforced with advanced smart-lattice composites that glow subtly to reflect the time of day or mood.
# - Roofs and ornamentation: ornate ridge beasts, gold finials, and blue-green ceramic tiles. Every roof is a living system, with nano-grow plants along the crests that help regulate microclimates and provide shade.
# - The Palace Museum district: the image’s feel is preserved here—granite courtyards, carved doors, and a grand gate that opens to a courtyard filled with visitors. The signs are in aging wood script and holographic callouts, part tradition, part information network.
# - Public spaces: wide plazas laid out for millions to gather, with tiered stone seating that doubles as solar collectors. The air smells of lacquer, tea steam, and incense used in ceremonial routines.
#
# Government and society
# - Ruling structure: Jingdu is governed by the Celestial Council, a cooperative of human leaders and AIs known as Oracles. The Emperor/Empress acts as a symbolic unifier and chief steward rather than a sovereign in the old sense.
# - Law and etiquette: Confucian-influenced etiquette remains central, but it’s augmented by transparent, AI-assisted governance. Decisions are discussed in public forums, with holographic records of every vote and debate.
# - Residency and classes: many families live in multi-story courtyards designed to adapt to climate and family size. Citizens wear smart textiles that respond to temperature and mood, changing color subtly as social rituals begin.
#
# Culture, art, and daily life
# - Arts: a living tradition of court music, calligraphy, and opera performed in open-air amphitheaters. The text is often both spoken language and streams of data projected in the air for the audience to read.
# - Religion and philosophy: a syncretic blend of ancient Daoist and Confucian ideas with a modern pantheon of technology spirits—think sages who personify algorithms and weather systems.
# - Daily rhythm: mornings begin with markets and tea houses where AI sommeliers tune the brew to your health data. Afternoons are for study, engineering, or visits to the Palace Museum. Evenings feature lantern parades and drone-light performances that tell the city’s legends.
#
# Technology and infrastructure
# - Energy and environment: the city runs on a combination of tidal/solar microgrids and subterranean fusion nodes. The living roofs and walls manage humidity, air quality, and energy distribution.
# - Transportation: magnetic tramways along central ridges, autonomous carriages in the lanes, and pedestrian sky-walks that glow softly to guide foot traffic at night. Aerial taxis are shaped like crane birds and hover just above the rooftops.
# - Defense and safety: an integrated security network uses holographic barriers, climate-control domes to stave off extreme weather, and “mirror walls” that create distraction illusions to deter intruders without harming bystanders.
#
# Landmarks and sights
# - The Gate of Dawn: a colossal entry to the Imperial City with a ceremonial guards’ parade that doubles as a public performance.
# - Temple of the Recording Sky: a data temple where historians archive the realm’s memories, accessible to scholars and artists alike.
# - Hall of Nine Lanterns: a pavilion where visitors experience interactive light shows that translate the city’s legends into living color.
# - The Forbidden City Museum (the signage you see in the photo): a vast archive of dynastic artifacts housed in climate-stable chambers, with augmented reality guides that narrate the empire’s most pivotal decisions.
#
# Cuisine and culture
# - Food: street markets offer stewed lotus, steam buns with living yeast cultures, and nanotech-fueled soups that adjust mineral content to your needs.
# - Festivals: the Lantern of Nine Mists (a night-time festival with holographic fog, scent drones, and a chorus of drones singing in the air) and the Day of Quiet Columns, when the city pauses to reflect on its memories.
#
# Economy and foreign relations
# - Economy: a blend of cultural tourism, high-end manufacturing of precision components, and data services. The Palace Museum is the cultural engine, while the city’s ports handle interstellar and interplanetary trade routes.
# - Diplomacy: Jingdu sits at the heart of a network of allied capitals. It hosts grand summits in the Hall of Dawn where delegates arrive by orbital shuttle or dragon-ship, a symbolic nod to the city’s hybrid heritage.
#
# Visiting or exploring
# - Best time to visit: dawn or dusk, when the roofs catch a warm light and the city’s energy grid shifts from day to night rituals.
# - Etiquette: respect the ceremonial pathways, avoid touching preserved artifacts, and follow the AI guides when in sensitive areas.
# - What to look for: the precision of the timberwork and metalwork, the way light plays on the dragon-ornamented eaves, and the way the city blends memory with future in every corridor.
#
# If you’d like, I can tailor this capital further—different era of the dynasty, a harsher climate, or a more sci-fi edge (e.g., a spaceport district, orbital governance, or alien diplomacy). Would you prefer a version grounded in more traditional aesthetics or one that leans harder into futuristic technology?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.67it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# It sounds like the audio file contains a voice or some kind of audio input that repeats the words "Duration" and "Sample rate." The file is likely someone or something listing technical terms related to audio properties.
#
# If you want more specific details, such as duration, sample rate values, or more context, feel free to let me know or provide more information!
