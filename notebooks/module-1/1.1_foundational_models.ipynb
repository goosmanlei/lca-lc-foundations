# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or cities, so it has no capital.\n\nIf you’re thinking in a fictional or humorous context, you could call it something like Lunapolis, Selene City, or Moonhaven. For real life, there are only temporary human footprints and planned future bases, not a capital city. Want some more fictional options or a quick note on actual lunar bases?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 671, 'prompt_tokens': 13, 'total_tokens': 684, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DQxEn8RCSE7EhmOR3J5w1wpdK0e4z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d591d-a135-77e3-acb7-cdc3eeb29492-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 671, 'total_tokens': 684, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or population, so it has no capital.
#
# If you’re thinking of a fictional setting or a future lunar colony, tell me the universe or context and I can name the capital from that story or suggest a plausible name. Some common fictional options include names like Luna City, Selene, or Artemis.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DQx9VA5IsgGzbtFLIML3CA85b1Pux',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 783,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 704,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 796}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. If you’re thinking of fiction, you could invent a capital city name (e.g., Lunopolis or Artemis) and I can help brainstorm.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite with no permanent population or government.
#
# If you're asking about lunar settlements in science fiction, or future planned bases, those don't exist yet either - though various space agencies have discussed potential lunar outposts for the future.
#
# Is there something specific about the Moon or space exploration you'd like to know about?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way that Earth does. There are no countries, governments, or permanent human settlements on the Moon to designate a capital.
#
# However, if we were to imagine a capital based on **historical significance and human activity**, the **Sea of Tranquility (Mare Tranquillitatis)** would be a strong contender. This is where the **Apollo 11 mission** landed, and Neil Armstrong took his "one small step for man." It's the most famous and historically important location on the Moon from a human perspective.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
#     system_prompt="""
# You are a science ficion writer, create a space capital city at the users request.

# User: What is the capital of mars?
# Scifi Writer: Marsialis

# User: What is the capital of Venus?
# Scifi Writer: Venusovia
#     """,
    system_prompt="""
You are a science ficion writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries
    """,
)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='c413aae4-efa6-4fa8-8d88-07f08d7dad0f'),
#               AIMessage(content='Name: Selene Prime\n\nLocation: A vast, geothermally heated cavern system deep within the lunar mantle, accessed via a network of pressurized subterranean tunnels.\n\nVibe: Austere, Industrial, Resilient\n\nEconomy:\n*   **Helium-3 Extraction:** The primary driver, powering fusion reactors across the Sol system.\n*   **Advanced Robotics & Automation:** Manufacturing and maintenance of deep-mining and construction automatons.\n*   **Zero-G Manufacturing:** Production of ultra-pure materials and delicate components impossible to create with gravity.\n*   **Lunar Geothermal Energy:** Supplying power and heat to the city and surrounding lunar outposts.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d5932-e4a3-78d2-a325-7e6a1bd99e9a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 73, 'output_tokens': 136, 'total_tokens': 209, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# Name: Selene Prime
#
# Location: A vast, geothermally heated cavern system deep within the lunar mantle, accessed via a network of pressurized subterranean tunnels.
#
# Vibe: Austere, Industrial, Resilient
#
# Economy:
# *   **Helium-3 Extraction:** The primary driver, powering fusion reactors across the Sol system.
# *   **Advanced Robotics & Automation:** Manufacturing and maintenance of deep-mining and construction automatons.
# *   **Zero-G Manufacturing:** Production of ultra-pure materials and delicate components impossible to create with gravity.
# *   **Lunar Geothermal Energy:** Supplying power and heat to the city and surrounding lunar outposts.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='c0adf0ad-d4f8-4ef0-9aca-bf25ffc235d7'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='9ff32568-16ee-4172-a5bf-f7f3c0567b47', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='93befc80-ad6d-4f81-a34d-deef779666eb'),
#               AIMessage(content="Luna City isn't just a collection of domes and tunnels; it's a pulsating heart carved into the very bedrock of the Moon. Imagine vast, geothermally heated caverns, glowing with soft, bio-luminescent algae cultivated in nutrient-rich lunar regolith. The architecture is a blend of the organic and the engineered: crystalline structures that refract the distant Earthlight, seamlessly integrated with smooth, metallic alloys that can withstand micrometeorite impacts.\n\nThe city is organized into several strata. The **Upper Domes**, closest to the surface, are where the primary agricultural and atmospheric processing facilities hum, bathed in the filtered sunlight that streams through reinforced transparent sections. This is also where the grand observatories are situated, their massive lenses pointed outwards, forever gazing at the cosmos.\n\nBelow that lies the **Central Nexus**. This is the bustling heart of Luna City, a sprawling network of interconnected plazas, mag-lev transit tubes, and vibrant marketplaces. Here, you'll find the administrative buildings, the gleaming chrome towers of the major corporations that oversee lunar mining and orbital traffic, and the cultural hubs. Think holographic art installations that shift and morph with the emotions of the onlookers, and performance halls where gravity-defying acrobatics are the norm.\n\nThe lowest levels, the **Deep Veins**, are more utilitarian, housing the heavy industry, power generation (primarily fusion and geothermal), and the extensive hydroponic farms. But even here, there's a stark beauty – the rhythmic pulse of machinery, the soft glow of emergency lighting reflecting off polished obsidian-like surfaces, and the constant, low hum of life support systems.\n\nThe population of Luna City is a fascinating mix. You have the native Lunarians, born and raised in the lower gravity, their bodies adapted to the subtle differences. Then there are the Earthborn, the transient workers, scientists, and diplomats who bring with them the energy and anxieties of their home planet. And of course, there are the off-worlders, traders and explorers from across the solar system, adding a kaleidoscope of cultures and customs.\n\nThe air itself is a carefully controlled blend, crisp and clean, carrying the faint scent of ozone and cultivated flora. Sound travels differently in the lower gravity, so conversations have a slightly more resonant quality, and the distant clang of a maintenance drone can echo for surprising distances.\n\nLuna City is a testament to human ingenuity and resilience, a beacon of civilization perched on the desolate, yet beautiful, surface of Earth's closest celestial neighbor. It's a place where the past, present, and future of humanity are constantly being negotiated, under the watchful eye of a silent, distant blue marble.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d5930-ce28-7743-9575-cb5404a16c92-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 84, 'output_tokens': 541, 'total_tokens': 625, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Name: Luna City
#
# Location: A vast, geothermally heated cavern system beneath the Sea of Tranquility on Earth's Moon. The primary access points are massive, reinforced dome structures that pierce the lunar surface.
#
# Vibe: Serene, Sophisticated, Resilient
#
# Economy:
# *   **Information & Data Hub:** Luna City is the central nexus for the galaxy's data streams, housing immense server farms cooled by the Moon's vacuum and powered by fusion. It's the primary location for interstellar communication relays and advanced AI development.
# *   **Lunar Resource Extraction & Processing:** While not the sole extractor, Luna City is the administrative and high-tech processing center for Helium-3, rare earth minerals, and the unique crystalline structures found within lunar regolith.
# *   **Advanced Manufacturing & Fabrication:** The city boasts cutting-edge nanofactories and zero-gravity fabrication plants, producing high-precision components for starships, orbital habitats, and sophisticated scientific instruments.
# *   **Cultural & Diplomatic Center:** As the capital, Luna City hosts the Galactic Council, numerous embassies, and is a hub for interstellar tourism, art, and philosophical discourse, attracting beings from across known space.
