# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='c87c4a51-1b82-48b0-aabb-45d142ae07cd'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1106, 'prompt_tokens': 1229, 'total_tokens': 2335, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DRaXy2FCZbvtCm6cLFUQDNBgAlUZ8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d621f-3b16-75a3-a88a-b4183a588c2a-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2027', 'departureDateFlexRange': 0, 'passengers': {'adults': 1, 'children': 0, 'infants': 0}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'USD', 'locale': 'en'}, 'id': 'call_XlTTTwoqLXcKpb1A0MLzR25N', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 1106, 'total_tokens': 2335, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T08:05:00.000Z",\n      "local": "2027-03-31T01:05:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T04:15:00.000Z",\n      "local": "2027-04-01T13:15:00.000"\n    },\n    "totalDurationInSeconds": 72600,\n    "durationInSeconds": 72600,\n    "price": 555,\n    "deepLink": "https://on.kiwi.com/WIlYHZ",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:35:00.000Z",\n          "local": "2027-04-01T05:35:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-01T00:50:00.000Z",\n          "local": "2027-04-01T08:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T08:05:00.000Z",\n      "local": "2027-03-31T01:05:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T07:35:00.000Z",\n      "local": "2027-04-01T16:35:00.000"\n    },\n    "totalDurationInSeconds": 84600,\n    "durationInSeconds": 84600,\n    "price": 555,\n    "deepLink": "https://on.kiwi.com/QYcUrS",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:35:00.000Z",\n          "local": "2027-04-01T05:35:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-01T04:15:00.000Z",\n          "local": "2027-04-01T12:15:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:50:00.000Z",\n      "local": "2027-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T03:25:00.000Z",\n      "local": "2027-04-01T12:25:00.000"\n    },\n    "totalDurationInSeconds": 70500,\n    "durationInSeconds": 70500,\n    "price": 730,\n    "deepLink": "https://on.kiwi.com/KolMNY",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:40:00.000Z",\n          "local": "2027-04-01T05:40:00.000"\n        },\n        "departure": {\n          "utc": "2027-03-31T23:55:00.000Z",\n          "local": "2027-04-01T07:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:25:00.000Z",\n      "local": "2027-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T03:25:00.000Z",\n      "local": "2027-04-01T12:25:00.000"\n    },\n    "totalDurationInSeconds": 72000,\n    "durationInSeconds": 72000,\n    "price": 730,\n    "deepLink": "https://on.kiwi.com/s52vfS",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:15:00.000Z",\n          "local": "2027-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2027-03-31T23:55:00.000Z",\n          "local": "2027-04-01T07:55:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:50:00.000Z",\n      "local": "2027-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T04:25:00.000Z",\n      "local": "2027-04-01T13:25:00.000"\n    },\n    "totalDurationInSeconds": 74100,\n    "durationInSeconds": 74100,\n    "price": 730,\n    "deepLink": "https://on.kiwi.com/ ...
#               AIMessage(content='I didn’t find any direct (non-stop) flights from San Francisco to Tokyo on March 31. Here are the best one-stop options I found (via Taipei) with the cheapest price and the shortest duration.\n\n| Route | Times (local) | Cabin | Return route | Return Times | Return Cabin | Price (USD) | Deep link |\n|---|---|---|---|---|---|---|---|\n| SFO → TPE → NRT | 31/03 01:05 → 01/04 13:15 (20h 10m) | M | — | — | — | 555 | https://on.kiwi.com/WIlYHZ |\n| SFO → TPE → NRT | 31/03 01:05 → 01/04 16:35 (23h 30m) | M | — | — | — | 555 | https://on.kiwi.com/QYcUrS |\n| SFO → TPE → NRT | 31/03 00:50 → 01/04 12:25 (16h 25m) | M | — | — | — | 883 | https://on.kiwi.com/as9fye |\n\nBest options summary:\n- Cheapest: USD 555 flights (both via Taipei) offer solid prices but involve a layover in Taipei.\n- Shortest among these options: 16h 25m via Taipei for USD 883.\n\nRecommendation: If you can be flexible by shifting dates or accepting one-stop itineraries, the Taipei-stop options above are your best bet price-wise. If you’d like, I can search nearby dates or consider Tokyo’s other airports (HND/NRT) to try to find a nonstop option.\n\nWishing you a fantastic trip! Fun fact: Tokyo is home to the busiest street crossing in the world at Shibuya Crossing, where hundreds of people cross in all directions in a single moment.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10273, 'prompt_tokens': 5298, 'total_tokens': 15571, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 9856, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DRaYfxmWmbXewrDWYXXW7dqMvsSaC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d621f-e21f-7422-8c1b-ef9201a8ac7f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5298, 'output_tokens': 10273, 'total_tokens': 15571, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 9856}})]}

# %%
print(response["messages"][-1].content)
# Out:
# I didn’t find any direct (non-stop) flights from San Francisco to Tokyo on March 31. Here are the best one-stop options I found (via Taipei) with the cheapest price and the shortest duration.
#
# | Route | Times (local) | Cabin | Return route | Return Times | Return Cabin | Price (USD) | Deep link |
# |---|---|---|---|---|---|---|---|
# | SFO → TPE → NRT | 31/03 01:05 → 01/04 13:15 (20h 10m) | M | — | — | — | 555 | https://on.kiwi.com/WIlYHZ |
# | SFO → TPE → NRT | 31/03 01:05 → 01/04 16:35 (23h 30m) | M | — | — | — | 555 | https://on.kiwi.com/QYcUrS |
# | SFO → TPE → NRT | 31/03 00:50 → 01/04 12:25 (16h 25m) | M | — | — | — | 883 | https://on.kiwi.com/as9fye |
#
# Best options summary:
# - Cheapest: USD 555 flights (both via Taipei) offer solid prices but involve a layover in Taipei.
# - Shortest among these options: 16h 25m via Taipei for USD 883.
#
# Recommendation: If you can be flexible by shifting dates or accepting one-stop itineraries, the Taipei-stop options above are your best bet price-wise. If you’d like, I can search nearby dates or consider Tokyo’s other airports (HND/NRT) to try to find a nonstop option.
#
# Wishing you a fantastic trip! Fun fact: Tokyo is home to the busiest street crossing in the world at Shibuya Crossing, where hundreds of people cross in all directions in a single moment.
